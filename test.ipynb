# %% [markdown]
# # Testdaten
#
# Hier kønnte ihre Werbung stehen

# %%
print("Hallo")

# %%
import requests
response = requests.get("http://localhost:8000/customers")
print(response.json())

# %%
import requests

customer = {
    "first_name": "Sebastian",
    "last_name": "Heitmann",
    "email": "me@sebastian-heitmann.dev",
    "phone": "12341234",
    "address": "irgendwonirgendow",
    "city": "Tosted City",
    "state": "Niedersachsen",
    "zip_code": "1337",
    "registration_date": "2022-12-06",
    "customer_type": "Individual"
}
response = requests.post("http://localhost:8000/customer", json = customer)
print(response)
# Out:
# <Response [422]>
